# %% [markdown]
# <a href="https://colab.research.google.com/github/dandan682/Python-Mini-Bootcamp/blob/main/Semana_01_%7C_Python_Mini_Bootcamp_%7C_Bernardo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook de Bernardo Castro
#
# Estoy tomando este bootcamp porque quiero aprender a programar en python.
#
# - Aprender las bases de Python.
# - Entender cómo funciona la programación orientada a objetos.
# - Construir mi primer proyecto.

# %%
print("Hola mundo")
# Out:
# Hola mundo

# %%
print("Bernardo Castro")
# Out:
# Bernardo Castro

# %%
print(58)
# Out:
# 58

# %%
print("Ciudad de México")
# Out:
# Ciudad de México
